# %% [markdown]
# # Convolutional Neural Networks
# This notebook will guide you through the use of the `keras` package to train convolutional neural networks for handwritten digits classification. You are going to use the `mnist` dataset from LeCun et al. 1998.

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
from matplotlib import pyplot as pl

import tensorflow as tf
from tensorflow import keras as keras
from sklearn import metrics as me

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5f512bcd2d05> in <module>
#       2 from matplotlib import pyplot as pl
#       3
# ----> 4 import tensorflow as tf
#       5 from tensorflow import keras as keras
#       6 from sklearn import metrics as me
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ### Load the `mnist` dataset and normalize in the range [0, 1]

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

n_train, height, width = X_train.shape
n_test, _, _ = X_test.shape

X_train = np.expand_dims(X_train, axis=3).astype(np.float32)
X_test = np.expand_dims(X_test, axis=3).astype(np.float32)

X_train /= 255.0
X_test /= 255.0

n_classes = 10

print(n_train, 'train samples')
print(n_test, 'test samples')

# convert class vectors to binary class matrices
Y_train = keras.utils.to_categorical(y_train, n_classes)
Y_test = keras.utils.to_categorical(y_test, n_classes)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-590d3e9be53d> in <module>
# ----> 1 (X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
#       2
#       3 n_train, height, width = X_train.shape
#       4 n_test, _, _ = X_test.shape
#       5
#
# NameError: name 'keras' is not defined

# %%
pl.Figure(figsize=(16,10))
for i in range(30):
    pl.subplot(5,6,i+1)
    j = np.random.randint(0,X_train.shape[0])
    pl.imshow(X_train[j,:,:,0])
    pl.title(y_train[j])
    pl.axis('off')

# %% [markdown]
# ### Make sure that the dimension ordering matches the backend (tensorflow)

# %%
print(keras.backend.image_data_format())
# Out:
# channels_last

# %% [markdown]
# ### Create the CNN and show its architecture (Functional API)

# %%
l0 = keras.layers.Input(shape=(height, width, 1), name='l0')

l1 = keras.layers.Conv2D(9, (5, 5), padding='same', activation='relu', name='l1')(l0)
l1_mp = keras.layers.MaxPooling2D(pool_size=(2, 2), name='l1_mp')(l1)

l2 = keras.layers.Conv2D(9, (5, 5), padding='same', activation='relu', name='l2')(l1_mp)
l2_mp = keras.layers.MaxPooling2D(pool_size=(2, 2), name='l2_mp')(l2)

l3 = keras.layers.Conv2D(16, (3, 3), padding='same', activation='relu', name='l3')(l2_mp)
l3_mp = keras.layers.MaxPooling2D(pool_size=(2, 2), name='l3_mp')(l3)

flat = keras.layers.Flatten(name='flat')(l3_mp)

l4 = keras.layers.Dense(25, activation='relu', name='l4')(flat)

l5 = keras.layers.Dense(n_classes, activation='softmax', name='l5')(l4)

model = keras.models.Model(inputs=l0, outputs=l5)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# l0 (InputLayer)              [(None, 28, 28, 1)]       0
# _________________________________________________________________
# l1 (Conv2D)                  (None, 28, 28, 9)         234
# _________________________________________________________________
# l1_mp (MaxPooling2D)         (None, 14, 14, 9)         0
# _________________________________________________________________
# l2 (Conv2D)                  (None, 14, 14, 9)         2034
# _________________________________________________________________
# l2_mp (MaxPooling2D)         (None, 7, 7, 9)           0
# _________________________________________________________________
# l3 (Conv2D)                  (None, 7, 7, 16)          1312
# _________________________________________________________________
# l3_mp (MaxPooling2D)         (None, 3, 3, 16)          0
# _________________________________________________________________
# flat (Flatten)               (None, 144)               0
# _________________________________________________________________
# l4 (Dense)                   (None, 25)                3625
# _________________________________________________________________
# l5 (Dense)                   (None, 10)                260
# =================================================================
# Total params: 7,465
# Trainable params: 7,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define some constants and train de CNN

# %%
batch_size = 128
n_epoch = 10

model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.SGD(), metrics=['accuracy'])

history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=n_epoch, verbose=1,
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 16s 32ms/step - loss: 2.2798 - accuracy: 0.1778 - val_loss: 2.0204 - val_accuracy: 0.3596
# Epoch 2/10
# 469/469 [==============================] - 15s 31ms/step - loss: 1.3963 - accuracy: 0.5848 - val_loss: 0.3167 - val_accuracy: 0.9069
# Epoch 3/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.2868 - accuracy: 0.9139 - val_loss: 0.2033 - val_accuracy: 0.9365
# Epoch 4/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.1974 - accuracy: 0.9395 - val_loss: 0.1533 - val_accuracy: 0.9505
# Epoch 5/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.1649 - accuracy: 0.9487 - val_loss: 0.1516 - val_accuracy: 0.9523
# Epoch 6/10
# 469/469 [==============================] - 15s 31ms/step - loss: 0.1511 - accuracy: 0.9536 - val_loss: 0.1166 - val_accuracy: 0.9620
# Epoch 7/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.1280 - accuracy: 0.9600 - val_loss: 0.1110 - val_accuracy: 0.9652
# Epoch 8/10
# 469/469 [==============================] - 14s 30ms/step - loss: 0.1200 - accuracy: 0.9627 - val_loss: 0.1095 - val_accuracy: 0.9650
# Epoch 9/10
# 469/469 [==============================] - 14s 31ms/step - loss: 0.1182 - accuracy: 0.9638 - val_loss: 0.1049 - val_accuracy: 0.9653
# Epoch 10/10
# 469/469 [==============================] - 14s 29ms/step - loss: 0.1074 - accuracy: 0.9660 - val_loss: 0.0918 - val_accuracy: 0.9693

# %% [markdown]
# ### Show the performance of the model

# %%
pl.plot(history.history['loss'], label='Training')
pl.plot(history.history['val_loss'], label='Testing')
pl.legend()
pl.grid()

score = model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.09184790402650833
# Test accuracy: 0.9692999720573425

# %% [markdown]
# Confusion matrix

# %%
pred_probas = model.predict_on_batch(X_test)
pred_classes = np.argmax(pred_probas, axis=-1)
me.confusion_matrix(y_test, pred_classes)
# Out:
# array([[ 969,    0,    2,    0,    0,    1,    4,    2,    2,    0],
#        [   0, 1123,    4,    0,    1,    0,    3,    1,    3,    0],
#        [   9,    5,  999,    3,    2,    0,    1,    6,    6,    1],
#        [   0,    0,   13,  971,    0,   12,    0,    7,    5,    2],
#        [   1,    0,    2,    0,  963,    0,    3,    1,    0,   12],
#        [   5,    1,    0,   12,    2,  844,   13,    1,    5,    9],
#        [   9,    5,    0,    0,    6,    2,  935,    0,    1,    0],
#        [   2,    2,   10,    2,    3,    0,    0,  998,    1,   10],
#        [  10,    1,   12,    4,    3,    1,    6,    4,  925,    8],
#        [   5,    6,    3,    6,   13,    3,    0,    5,    2,  966]])
